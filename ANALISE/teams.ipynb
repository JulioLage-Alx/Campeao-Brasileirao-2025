# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
teams_data = pd.read_csv(r"C:\Users\Julio Lage\Documents\GitHub\Campeao-Brasileirao-2025\DATA\teams.csv")

# %%
teams_data
# Out:
#                     team acronym                           full_name  founded  \
# 0        América Mineiro     AMG               America Futebol Clube     1912
# 1             América-RN     AFC                    America de Natal     1915
# 2   Athletico Paranaense     CAP           Club Athletico Paranaense     1924
# 3    Atlético Goianiense     ACG           Atletico Clube Goianiense     1937
# 4       Atlético Mineiro     CAM              Clube Atletico Mineiro     1908
# 5                   Avaí     AVA                  Avai Esporte Clube     1923
# 6                  Bahia     ECB                 Esporte Clube Bahia     1931
# 7                Barueri     BAR         Gremio Barueri Futebol Ltda     1989
# 8               Botafogo     BOT       Botafogo de Futebol e Regatas     1904
# 9            Brasiliense     BRA           Brasiliense Futebol Clube     2000
# 10                 Ceará     CEA                 Ceara Sporting Club     1914
# ...
